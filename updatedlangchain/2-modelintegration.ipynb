# %% [markdown]
# ### Models Integration With OpenAI, Groq ,Google Gemini

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("groq:llama-3.1-8b-instant")
model
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001A3A4D1D400>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001A3A4D1E120>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
## invoke the model
response=model.invoke("Hello How are you") 
response
# Out:
# AIMessage(content="Hello. I'm functioning properly, thanks for asking. How can I assist you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 39, 'total_tokens': 58, 'completion_time': 0.021558847, 'completion_tokens_details': None, 'prompt_time': 0.001829059, 'prompt_tokens_details': None, 'queue_time': 0.158630619, 'total_time': 0.023387906}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ea0fb-79f8-78a2-acca-0ebe99b92c88-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 19, 'total_tokens': 58})

# %%
### ChatOpenAI

from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-4.1")
response=model.invoke("Hello How are you")
response
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 5
#       1 ### ChatOpenAI
#       2
#       3 from langchain_openai import ChatOpenAI
#       4 model=ChatOpenAI(model="gpt-4.1")
# ----> 5 response=model.invoke("Hello How are you")
#       6 response
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1667, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1665     _handle_openai_bad_request(e)
#    1666 except openai.APIError as e:
# -> 1667     _handle_openai_api_error(e)
#    1668 except Exception as e:
#    1669     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1662, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1655         return _construct_lc_result_from_responses_api(
#    1656             response,
#    1657             schema=original_schema_obj,
#    1658             metadata=generation_info,
#    1659             output_version=self.output_version,
#    1660         )
#    1661     else:
# -> 1662         raw_response = self.client.with_raw_response.create(**payload)
#    1663         response = raw_response.parse()
#    1664 except openai.BadRequestError as e:
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1215, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1168 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1169 def create(
#    1170     self,
#    (...)   1212     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1213 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1214     validate_response_format(response_format)
# -> 1215     return self._post(
#    1216         "/chat/completions",
#    1217         body=maybe_transform(
#    1218             {
#    1219                 "messages": messages,
#    1220                 "model": model,
#    1221                 "audio": audio,
#    1222                 "frequency_penalty": frequency_penalty,
#    1223                 "function_call": function_call,
#    1224                 "functions": functions,
#    1225                 "logit_bias": logit_bias,
#    1226                 "logprobs": logprobs,
#    1227                 "max_completion_tokens": max_completion_tokens,
#    1228                 "max_tokens": max_tokens,
#    1229                 "metadata": metadata,
#    1230                 "modalities": modalities,
#    1231                 "n": n,
#    1232                 "parallel_tool_calls": parallel_tool_calls,
#    1233                 "prediction": prediction,
#    1234                 "presence_penalty": presence_penalty,
#    1235                 "prompt_cache_key": prompt_cache_key,
#    1236                 "prompt_cache_retention": prompt_cache_retention,
#    1237                 "reasoning_effort": reasoning_effort,
#    1238                 "response_format": response_format,
#    1239                 "safety_identifier": safety_identifier,
#    1240                 "seed": seed,
#    1241                 "service_tier": service_tier,
#    1242                 "stop": stop,
#    1243                 "store": store,
#    1244                 "stream": stream,
#    1245                 "stream_options": stream_options,
#    1246                 "temperature": temperature,
#    1247                 "tool_choice": tool_choice,
#    1248                 "tools": tools,
#    1249                 "top_logprobs": top_logprobs,
#    1250                 "top_p": top_p,
#    1251                 "user": user,
#    1252                 "verbosity": verbosity,
#    1253                 "web_search_options": web_search_options,
#    1254             },
#    1255             completion_create_params.CompletionCreateParamsStreaming
#    1256             if stream
#    1257             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1258         ),
#    1259         options=make_request_options(
#    1260             extra_headers=extra_headers,
#    1261             extra_query=extra_query,
#    1262             extra_body=extra_body,
#    1263             timeout=timeout,
#    1264             security={"bearer_auth": True},
#    1265         ),
#    1266         cast_to=ChatCompletion,
#    1267         stream=stream or False,
#    1268         stream_cls=Stream[ChatCompletionChunk],
#    1269     )
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
### ChatOpenAI
from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-4.1")
response=model.invoke("Hello How are you")
response
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 ### ChatOpenAI
#       2 from langchain_openai import ChatOpenAI
#       3 model=ChatOpenAI(model="gpt-4.1")
# ----> 4 response=model.invoke("Hello How are you")
#       5 response
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1667, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1665     _handle_openai_bad_request(e)
#    1666 except openai.APIError as e:
# -> 1667     _handle_openai_api_error(e)
#    1668 except Exception as e:
#    1669     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1662, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1655         return _construct_lc_result_from_responses_api(
#    1656             response,
#    1657             schema=original_schema_obj,
#    1658             metadata=generation_info,
#    1659             output_version=self.output_version,
#    1660         )
#    1661     else:
# -> 1662         raw_response = self.client.with_raw_response.create(**payload)
#    1663         response = raw_response.parse()
#    1664 except openai.BadRequestError as e:
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1215, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1168 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1169 def create(
#    1170     self,
#    (...)   1212     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1213 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1214     validate_response_format(response_format)
# -> 1215     return self._post(
#    1216         "/chat/completions",
#    1217         body=maybe_transform(
#    1218             {
#    1219                 "messages": messages,
#    1220                 "model": model,
#    1221                 "audio": audio,
#    1222                 "frequency_penalty": frequency_penalty,
#    1223                 "function_call": function_call,
#    1224                 "functions": functions,
#    1225                 "logit_bias": logit_bias,
#    1226                 "logprobs": logprobs,
#    1227                 "max_completion_tokens": max_completion_tokens,
#    1228                 "max_tokens": max_tokens,
#    1229                 "metadata": metadata,
#    1230                 "modalities": modalities,
#    1231                 "n": n,
#    1232                 "parallel_tool_calls": parallel_tool_calls,
#    1233                 "prediction": prediction,
#    1234                 "presence_penalty": presence_penalty,
#    1235                 "prompt_cache_key": prompt_cache_key,
#    1236                 "prompt_cache_retention": prompt_cache_retention,
#    1237                 "reasoning_effort": reasoning_effort,
#    1238                 "response_format": response_format,
#    1239                 "safety_identifier": safety_identifier,
#    1240                 "seed": seed,
#    1241                 "service_tier": service_tier,
#    1242                 "stop": stop,
#    1243                 "store": store,
#    1244                 "stream": stream,
#    1245                 "stream_options": stream_options,
#    1246                 "temperature": temperature,
#    1247                 "tool_choice": tool_choice,
#    1248                 "tools": tools,
#    1249                 "top_logprobs": top_logprobs,
#    1250                 "top_p": top_p,
#    1251                 "user": user,
#    1252                 "verbosity": verbosity,
#    1253                 "web_search_options": web_search_options,
#    1254             },
#    1255             completion_create_params.CompletionCreateParamsStreaming
#    1256             if stream
#    1257             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1258         ),
#    1259         options=make_request_options(
#    1260             extra_headers=extra_headers,
#    1261             extra_query=extra_query,
#    1262             extra_body=extra_body,
#    1263             timeout=timeout,
#    1264             security={"bearer_auth": True},
#    1265         ),
#    1266         cast_to=ChatCompletion,
#    1267         stream=stream or False,
#    1268         stream_cls=Stream[ChatCompletionChunk],
#    1269     )
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\LOVE\Desktop\rag\langchainupdated\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
response.content
# Out:
# "Hello. I'm functioning properly, thanks for asking. How can I assist you today?"

# %% [markdown]
# ### Google Gemini Model Integration

# %%
import os 
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("why do parrots talk?")
response.content
# Out:
# 'Parrots talk for a fascinating combination of reasons, rooted in their biology, social behavior, and cognitive abilities. It\'s not just a random mimicry; there\'s a purpose behind their vocalizations. Here are the primary drivers:\n\n**1. Social Bonding and Communication:**\n\n* **Flock Animals:** Parrots are highly social creatures that live in flocks in the wild. Vocalizations are crucial for maintaining group cohesion, identifying individuals, and coordinating activities like foraging, migrating, and warning of danger.\n* **"Contact Calls":** They use specific calls to stay in touch with their flock members, especially when they can\'t see each other. This is a fundamental aspect of their social structure.\n* **Reinforcing Bonds:** Mimicking sounds, including those of their flock mates, can be a way to reinforce social bonds and show they are part of the group.\n\n**2. Learning and Mimicry:**\n\n* **Vocal Learners:** Parrots are exceptional vocal learners, meaning they are genetically predisposed to learn and reproduce sounds from their environment. This is a key difference between them and many other bird species that have more innate vocalizations.\n* **Intelligence and Cognitive Abilities:** Their ability to learn complex vocalizations is linked to their intelligence. They have well-developed auditory processing centers in their brains.\n* **Testing and Exploration:** Mimicking sounds can be a way for young parrots to practice their vocal abilities, explore their environment, and learn about the sounds that are important.\n\n**3. Gaining Attention and Resources (in captivity):**\n\n* **Learned Behavior:** In a captive environment, parrots quickly learn that making sounds, including human speech, can elicit a response from their owners. This response often involves attention, treats, or interaction.\n* **"If it works, I\'ll do it again":** They associate vocalizations with positive reinforcement. If saying "hello" gets them a head scratch, they\'ll repeat "hello."\n* **Mimicking Key Sounds:** They often focus on sounds that are frequently heard or associated with positive experiences, like their owner\'s voice, the doorbell, or the sound of food being prepared.\n\n**4. Expressing Emotions and Needs (to a degree):**\n\n* **Distress/Fear:** A parrot might screech loudly if it\'s scared or distressed.\n* **Excitement/Joy:** They can vocalize with happy chirps and squawks when they\'re content or excited.\n* **Frustration:** If a parrot is bored or frustrated, it might vocalize to try and get attention or a change in its environment.\n* **"Talking" as a Form of Interaction:** While they don\'t understand the *meaning* of human words in the same way we do, they learn to associate specific sounds with specific outcomes or contexts. For example, a parrot might say "goodbye" when you leave the room, not because it understands the concept of parting, but because it has learned that sound is associated with that event.\n\n**Important Distinctions:**\n\n* **Not Understanding Meaning:** It\'s crucial to understand that parrots don\'t grasp the semantic meaning of human language. They are mimicking sounds they hear and associating them with specific contexts or desired outcomes.\n* **Intentionality:** While they are not consciously "trying to communicate" in the human sense, their vocalizations are often intentional in the sense that they are trying to achieve a desired result (attention, food, etc.) or respond to an environmental cue.\n\nIn summary, parrots talk because they are highly social, intelligent, and vocal learning animals. In the wild, it\'s for survival and flock cohesion. In captivity, it\'s a learned behavior driven by their desire for interaction, attention, and reinforcement from their human companions.'

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI


model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots talk for a variety of fascinating reasons, and it\'s a complex behavior driven by a combination of their **biology, social nature, and cognitive abilities.** Here\'s a breakdown of the primary drivers:\n\n**1. Mimicry and Vocal Learning:**\n\n*   **Exceptional Vocal Learners:** Parrots are among the most accomplished vocal learners in the animal kingdom, meaning they can learn and reproduce sounds from their environment. This is a fundamental biological adaptation that allows them to develop complex vocal repertoires.\n*   **The Syringeal Structure:** Their vocal apparatus, the syrinx, is highly developed and flexible, allowing them to produce a wide range of sounds, including human speech.\n*   **Social Bonding and Communication:** In the wild, parrots use vocalizations to:\n    *   **Maintain Flock Cohesion:** They call out to each other to stay in touch, especially when foraging or flying.\n    *   **Identify Individuals:** Each parrot has a unique call, like a "name," that allows them to recognize each other.\n    *   **Communicate Danger:** Alarm calls warn the flock of predators.\n    *   **Courtship and Pair Bonding:** Elaborate vocalizations are used to attract mates and strengthen pair bonds.\n    *   **Coordinate Activities:** They might use specific calls to signal when it\'s time to fly or return to roost.\n\n**2. Cognitive Abilities and Intelligence:**\n\n*   **Problem-Solving and Learning:** Parrots are highly intelligent birds. Their ability to talk is linked to their capacity for learning, understanding context, and even forming associations.\n*   **Understanding and Association (to some extent):** While they don\'t understand language in the same way humans do, many parrots can learn to associate specific words or phrases with objects, actions, or rewards. For example, they might learn that "cracker" means they\'ll get a treat.\n*   **Cognitive Stimulation:** Talking can be a form of mental stimulation for parrots. It keeps their minds active and engaged.\n\n**3. Social Interaction and Attention Seeking:**\n\n*   **Social Creatures:** Parrots are highly social animals and thrive on interaction. In captivity, their human "flock" becomes their primary social group.\n*   **Seeking Attention:** When a parrot hears humans talking, they often learn that vocalizing can elicit a response. This can be a way for them to get attention, participate in the "conversation," or simply feel included.\n*   **Mimicking Social Cues:** They may mimic sounds they hear regularly, including human speech, because it\'s part of the social environment they are immersed in.\n\n**4. Playfulness and Entertainment:**\n\n*   **Enjoyment of Sounds:** Parrots can simply enjoy the act of making sounds and experimenting with different vocalizations. They may play with words and phrases, much like a child plays with new toys.\n*   **Reinforcement:** When their vocalizations are met with positive reinforcement (like praise, treats, or interaction), they are more likely to repeat them.\n\n**In summary, parrots talk because:**\n\n*   **Biologically, they are built for vocal learning and mimicry.**\n*   **Socially, vocalizations are crucial for their survival and bonding in the wild, and they extend this to their human families.**\n*   **Cognitively, they are intelligent enough to learn associations and find vocal interaction stimulating and rewarding.**\n*   **They often use talking to seek attention, participate in their environment, and simply for the enjoyment of making noise.**\n\nIt\'s important to remember that while parrots can learn to say many words and phrases, their understanding is generally associative rather than conceptual, like human language comprehension. However, their ability to mimic and engage in vocal interactions remains one of the most captivating aspects of these remarkable birds.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_rat ...
